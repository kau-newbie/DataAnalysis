# %% [markdown]
# # wine data

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_wine
wine =  load_wine(as_frame=True)

# %%
type(wine)
# Out:
# sklearn.utils.Bunch

# %%
wine
# Out:
# {'data':      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
#  0      14.23        1.71  2.43               15.6      127.0           2.80
#  1      13.20        1.78  2.14               11.2      100.0           2.65
#  2      13.16        2.36  2.67               18.6      101.0           2.80
#  3      14.37        1.95  2.50               16.8      113.0           3.85
#  4      13.24        2.59  2.87               21.0      118.0           2.80
#  ..       ...         ...   ...                ...        ...            ...
#  173    13.71        5.65  2.45               20.5       95.0           1.68
#  174    13.40        3.91  2.48               23.0      102.0           1.80
#  175    13.27        4.28  2.26               20.0      120.0           1.59
#  176    13.17        2.59  2.37               20.0      120.0           1.65
#  177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
features=wine['data']

# %%
type(features)
# Out:
# pandas.core.frame.DataFrame

# %%
features.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# ...

# %%
type(wine['feature_names'])
# Out:
# list

# %%
feature_names= wine['feature_names']

# %%
feature_names
# Out:
# ['alcohol',
#  'malic_acid',
#  'ash',
#  'alcalinity_of_ash',
#  'magnesium',
#  'total_phenols',
#  'flavanoids',
#  'nonflavanoid_phenols',
#  'proanthocyanins',
#  'color_intensity',
#  'hue',
#  'od280/od315_of_diluted_wines',
#  'proline']

# %%
type(feature_names)
# Out:
# list

# %%
type(wine['frame'])
# Out:
# pandas.core.frame.DataFrame

# %%
dfw=wine['frame']

# %% [markdown]
# Data Set Information:
#
# These data are the results of a chemical analysis of wines grown in the same region in Italy but derived from three different cultivars. The analysis determined the quantities of 13 constituents found in each of the three types of wines.

# %% [markdown]
# ## 와인 종류를 판정할 것.

# %% [markdown]
# ### 데이터의 열 분석
# 1) Alcohol
# 2) Malic acid
# 3) Ash
# 4) Alcalinity of ash
# 5) Magnesium
# 6) Total phenols
# 7) Flavanoids
# 8) Nonflavanoid phenols
# 9) Proanthocyanins
# 10) Color intensity
# 11) Hue
# 12) OD280/OD315 of diluted wines
# 13) Proline

# %% [markdown]
# overall info. : http://wineeducation.com/wineismadeof.html#:~:text=Ash%3A%20On%20the%20average%20about%202.5%20g%2FL%20of,sodium%2C%20calcium%2C%20magnesium%2C%20iron%2C%20copper%2C%20lead%2C%20arsenic%2C%20etc.
#
# 1) Alcohol
#   > 도수(%)
#
# 2) Malic acid
#   > 말산(%): 많은 과일에서 주요 유 기산. 말산은 포도에 존재하며 대부분의 포도주에도 들어있는데 때때로 5 g/L 의 높은 농도로 존재한다. [8] 열매가 성숙해감에 따라 말산의 양은 감소하지만, 말산은 포도주의 시큼한 맛에 기여한다.
#
# 3) Ash
# > On the average about 2.5 g/L of ash are found in wine. 칼륨,나트륨,납,마그네슘 등등 토양에서 발견되는 다양한 원소들 포함.
#
# 4) Alcalinity of ash
#
# 5) Magnesium
#
# 6) Total phenols
# > Responsible for much of the flavor and body of wine, these are a major component of wine. Benzaldehyde (vanillin) and Benzoic acid (Vanillic and Gallic acids) are the phenolic compounds one tastes the most in wines.
#
# 7) Flavanoids
# > 플라보노이드(영어: flavonoid) 또는 바이오플라보노이드(영어: bioflavonoid) ("노랗다"라는 뜻의 라틴어 flavus에서 유래함)는 식물이나 균류의 이차대사산물의 일종이다.
#
# - 플라보노이드(flavonoids)는 노란색을 의미하는 라틴어인 플라부스(flavus)에서 유래하였고 플라본(flavone)을 기본 구조로 갖는 식물성색소로 잘 알려져 있으며...
# - 생태학적 역할뿐만 아니라 식품학적으로도 중요한 화합물 군에 속한다.
# - 플라보노이드는 화학 구조적으로 뼈대라고 할 수 있는 ‘비배당체(아글리콘/aglycone)’과 ‘당(sugar)’이 결합되어 있는 형태인‘배당체(glycoside)’로 주로 구성된다.
# - 아글리콘의 종류나 결합되어 있는 당의 종류, 결합 형태에 따라서 수 천 또는 수 만 종의 플라보노이드조합이 가능하며, 실제로 자연계에서 발견되는 플라보노이드의 종류는 수 천종에 달한다.
#
# 8) Nonflavanoid phenols
# >Non-flavonoid phenolics include several subclasses of importance to wine, in particular the hydroxycinnamates, stilbenes, and benzoic acids. The hydroxycinnamates and stilbenes are found in the grape, while the benzoic acids are found in the grape and in oak, so oak-treated wines will include additional phenolics from that source.
#
# 9) Proanthocyanins
# > Proanthocyanidins are condensed tannins with various pharmacological properties.
#
# 10) Color intensity
# > 명도
#
# 11) Hue
# > 채도
#
# 12) OD280/OD315 of diluted wines
# > This is a method for determining the protein concentration, which can determine the protein content of various wines.
#
# 13) Proline
# > 프롤린(영어: proline)은 α-아미노산 중 하나이며, 비필수아미노산에 속하고 단백질의 가수분해 과정을 통해 얻는다. 단백질성 아미노산은 보통 1차 아민이지만 프롤린은 2차 아민인 이차 아미노산이며 이전에는 이미노산(imino acid)이라고도 불렀다. 콜라겐 중에 하이드록시프롤린으로 다량 함유된다.

# %%
n_d=dfw['target']
n_d
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 173    2
# 174    2
# 175    2
# 176    2
# 177    2
# Name: target, Length: 178, dtype: int32

# %%
#for feat in wine['feature_names']:
 #   plt.title(feat)
  #  for i in range(3):
   #     dfw.loc[dfw['target'] == i, feat].plot(kind='hist', label=i, alpha=0.5)
    #plt.legend()
    #plt.show()

# %%
# 전체와 특정 class 히스토그램
for i in range(0,3):
    n_d=dfw['target']
    a=[[],[],[]]
    x=n_d.count()
    for j in range(0,x):
        if(n_d[j]==i):
            a[i].append(j)
    features_=wine['data'].loc[a[i],feature_names]
    for feat in wine['feature_names']:
            (wine['data'])[feat].plot(kind='hist',bins=10,label='total',alpha=0.5, edgecolor='k')
            features_[feat].plot(kind='hist', bins=10,label=i, edgecolor='k')
            plt.legend()
            plt.xlabel(feat)
            plt.show()

# %%
# 전체와 모든 class 히스토그램
for feat in wine['feature_names']:
    n_d2=dfw['target']
    a2=[[],[],[]]
    x2=n_d2.count()
    for i2 in range(0,3):
        for j in range(0,x2):
            if(n_d2[j]==i2):
                a2[i2].append(j)
        features_=wine['data'].loc[a2[i2],feature_names]
        features_[feat].plot(kind='hist', bins=10,label=i2,alpha=0.3)
    
    plt.legend()
    plt.xlabel(feat)
    plt.show()

# %% [markdown]
# ### 결정 트리 구조를 모델로 사용.

# %%
from sklearn import tree
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### 불균형 데이터인지 확인.

# %%
target_ = wine['target']

# %%
target_
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 173    2
# 174    2
# 175    2
# 176    2
# 177    2
# Name: target, Length: 178, dtype: int32

# %%
type(target_)
# Out:
# pandas.core.series.Series

# %%
target_.value_counts()
# Out:
# 1    71
# 0    59
# 2    48
# Name: target, dtype: int64

# %%
print(71/48, 59/48, 71/59)
# Out:
# 1.4791666666666667 1.2291666666666667 1.2033898305084745

# %%
# 종류1과 2사이에는 1.5배 가까이 차이난다.

# %% [markdown]
# #### 결손값 확인

# %%
features.isnull().sum()
# Out:
# alcohol                         0
# malic_acid                      0
# ash                             0
# alcalinity_of_ash               0
# magnesium                       0
# total_phenols                   0
# flavanoids                      0
# nonflavanoid_phenols            0
# proanthocyanins                 0
# color_intensity                 0
# hue                             0
# od280/od315_of_diluted_wines    0
# proline                         0
# dtype: int64

# %% [markdown]
# #### 특징량 x 리스트 만들기

# %%
col = ['alcohol'                       
,'malic_acid'                                                                                 
,'total_phenols'                   
,'flavanoids'                      
,'nonflavanoid_phenols'            
,'proanthocyanins'                 
,'color_intensity'                 
,'hue'                             
,'od280/od315_of_diluted_wines'    
,'proline']

# %%
x=features[col]
t_= wine['frame']
t=t_['target']

# %% [markdown]
# #### 훈련 데이터와 테스트 데이터의 분할

# %%
x_train, x_test, y_train, y_test=train_test_split(x,t,test_size=0.3, random_state=0)
x_train.shape
# Out:
# (124, 10)

# %% [markdown]
# #### 불균형 데이터 고려

# %%
model= tree.DecisionTreeClassifier(max_depth=5, random_state=0,
                                  class_weight='balanced')
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_depth=5, random_state=0)

# %% [markdown]
# #### 정답률 계산

# %%
model.score(X=x_test, y=y_test)
# Out:
# 0.9444444444444444

# %%
#0.94의 정답률.

# %% [markdown]
# #### 트리구조에서, 정답률을 조금 더 높일 수 있을까?
# 1. 데이터 개수를 증가시킨다.
# 2. 데이터 전처리의 수단을 바꾼다.
# 3. 모델을 학습할 때의 설정을 바꾼다.

# %% [markdown]
# 테스트사이즈 0.1

# %%
def learn(x, t, depth):
    x_train, x_test, y_train, y_test = train_test_split(x,t,test_size=0.1,random_state=0)
 
 
    model = tree.DecisionTreeClassifier(max_depth = depth,random_state =0, class_weight='balanced')
    model. fit(x_train, y_train)

    score =model.score(X=x_train, y=y_train)
    score2= model.score(X=x_test, y=y_test)
    return round(score, 3), round(score2, 3),model

# %%
def work():
    for depth in range(1,20):
        train_score, test_score, model = learn(x,t,depth=depth)
        s='train score: {}'
        s2= 'test score: {}'
        total_s='깊이{}: '+s+s2
        print(total_s.format(depth, train_score, test_score))
    return

# %%
work()
# Out:
# 깊이1: train score: 0.594test score: 0.556
# 깊이2: train score: 0.95test score: 0.944
# 깊이3: train score: 0.988test score: 0.944
# 깊이4: train score: 0.994test score: 0.944
# 깊이5: train score: 1.0test score: 0.944
# 깊이6: train score: 1.0test score: 0.944
# 깊이7: train score: 1.0test score: 0.944
# 깊이8: train score: 1.0test score: 0.944
# 깊이9: train score: 1.0test score: 0.944
# 깊이10: train score: 1.0test score: 0.944
# 깊이11: train score: 1.0test score: 0.944
# 깊이12: train score: 1.0test score: 0.944
# 깊이13: train score: 1.0test score: 0.944
# 깊이14: train score: 1.0test score: 0.944
# 깊이15: train score: 1.0test score: 0.944
# 깊이16: train score: 1.0test score: 0.944
# 깊이17: train score: 1.0test score: 0.944
# 깊이18: train score: 1.0test score: 0.944
# 깊이19: train score: 1.0test score: 0.944

# %% [markdown]
# 테스트사이즈 0.2

# %%
def learn(x, t, depth):
    x_train, x_test, y_train, y_test = train_test_split(x,t,test_size=0.2,random_state=0)
 
 
    model = tree.DecisionTreeClassifier(max_depth = depth,random_state =0, class_weight='balanced')
    model. fit(x_train, y_train)

    score =model.score(X=x_train, y=y_train)
    score2= model.score(X=x_test, y=y_test)
    return round(score, 3), round(score2, 3),model

# %%
work()
# Out:
# 깊이1: train score: 0.599test score: 0.528
# 깊이2: train score: 0.951test score: 0.917
# 깊이3: train score: 0.993test score: 0.917
# 깊이4: train score: 0.993test score: 0.917
# 깊이5: train score: 1.0test score: 0.917
# 깊이6: train score: 1.0test score: 0.917
# 깊이7: train score: 1.0test score: 0.917
# 깊이8: train score: 1.0test score: 0.917
# 깊이9: train score: 1.0test score: 0.917
# 깊이10: train score: 1.0test score: 0.917
# 깊이11: train score: 1.0test score: 0.917
# 깊이12: train score: 1.0test score: 0.917
# 깊이13: train score: 1.0test score: 0.917
# 깊이14: train score: 1.0test score: 0.917
# 깊이15: train score: 1.0test score: 0.917
# 깊이16: train score: 1.0test score: 0.917
# 깊이17: train score: 1.0test score: 0.917
# 깊이18: train score: 1.0test score: 0.917
# 깊이19: train score: 1.0test score: 0.917

# %% [markdown]
# ##### 테스트사이즈 0.3

# %%
def learn(x, t, depth):
    x_train, x_test, y_train, y_test = train_test_split(x,t,test_size=0.3,random_state=0)
 
 
    model = tree.DecisionTreeClassifier(max_depth = depth,random_state =0, class_weight='balanced')
    model. fit(x_train, y_train)

    score =model.score(X=x_train, y=y_train)
    score2= model.score(X=x_test, y=y_test)
    return round(score, 3), round(score2, 3),model

# %%
def work():
    for depth in range(1,20):
        train_score, test_score, model = learn(x,t,depth=depth)
        s='train score: {}'
        s2= 'test score: {}'
        total_s='깊이{}: '+s+s2
        print(total_s.format(depth, train_score, test_score))
    return

# %%
work()
# Out:
# 깊이1: train score: 0.589test score: 0.574
# 깊이2: train score: 0.952test score: 0.926
# 깊이3: train score: 0.992test score: 0.944
# 깊이4: train score: 0.992test score: 0.944
# 깊이5: train score: 1.0test score: 0.944
# 깊이6: train score: 1.0test score: 0.944
# 깊이7: train score: 1.0test score: 0.944
# 깊이8: train score: 1.0test score: 0.944
# 깊이9: train score: 1.0test score: 0.944
# 깊이10: train score: 1.0test score: 0.944
# 깊이11: train score: 1.0test score: 0.944
# 깊이12: train score: 1.0test score: 0.944
# 깊이13: train score: 1.0test score: 0.944
# 깊이14: train score: 1.0test score: 0.944
# 깊이15: train score: 1.0test score: 0.944
# 깊이16: train score: 1.0test score: 0.944
# 깊이17: train score: 1.0test score: 0.944
# 깊이18: train score: 1.0test score: 0.944
# 깊이19: train score: 1.0test score: 0.944

# %% [markdown]
# 테스트사이즈 0.4

# %%
def learn(x, t, depth):
    x_train, x_test, y_train, y_test = train_test_split(x,t,test_size=0.4,random_state=0)
 
 
    model = tree.DecisionTreeClassifier(max_depth = depth,random_state =0, class_weight='balanced')
    model. fit(x_train, y_train)

    score =model.score(X=x_train, y=y_train)
    score2= model.score(X=x_test, y=y_test)
    return round(score, 3), round(score2, 3),model

# %%
work()
# Out:
# 깊이1: train score: 0.613test score: 0.556
# 깊이2: train score: 0.972test score: 0.917
# 깊이3: train score: 0.991test score: 0.917
# 깊이4: train score: 0.991test score: 0.903
# 깊이5: train score: 1.0test score: 0.917
# 깊이6: train score: 1.0test score: 0.917
# 깊이7: train score: 1.0test score: 0.917
# 깊이8: train score: 1.0test score: 0.917
# 깊이9: train score: 1.0test score: 0.917
# 깊이10: train score: 1.0test score: 0.917
# 깊이11: train score: 1.0test score: 0.917
# 깊이12: train score: 1.0test score: 0.917
# 깊이13: train score: 1.0test score: 0.917
# 깊이14: train score: 1.0test score: 0.917
# 깊이15: train score: 1.0test score: 0.917
# 깊이16: train score: 1.0test score: 0.917
# 깊이17: train score: 1.0test score: 0.917
# 깊이18: train score: 1.0test score: 0.917
# 깊이19: train score: 1.0test score: 0.917

# %%
def learn(x, t, depth,k,l):
    x_train, x_test, y_train, y_test = train_test_split(x,t,test_size=k,random_state=l)
 
 
    model = tree.DecisionTreeClassifier(max_depth = depth,random_state =0, class_weight='balanced')
    model. fit(x_train, y_train)

    score =model.score(X=x_train, y=y_train)
    score2= model.score(X=x_test, y=y_test)
    return round(score, 3), round(score2, 3),model,score2

# %%
def work(tes_size,tes_ranseed):
    max_tscore=0
    for depth in range(1,20):
        train_score, test_score, model, sc = learn(x,t,depth=depth,k=tes_size,l=tes_ranseed)
        if(sc>max_tscore ):
            max_tscore = sc
        
    return max_tscore

# %%
a=[[],[],[],[],[],[],[],[],[]]
for i in range(1,10,1):
    for j in range(0,1000):
        a[i-1].append(work(i*0.1, j ))

# %%
for i in range(0,9):
    plt.hist(a[i],bins=[j*0.01 for j in range(1,101)],color="orange")
    plt.xlim([0.6,1])
    #mean
    m=sum(a[i])/len(a[i])
    #variance
    s=0
    for j in range(0,1000):
        s=s+((m-a[i][j])**2)
        v=s/(len(a[i])-1)
    plt.xlabel(f'test_size ={(i+1)*0.1}\nrandomseed 0~999, every case\'max test_score\nmean: {m:.2f}\n variance: {v:.4f}')
    plt.ylabel('count')
    plt.show()

# %% [markdown]
# #### 결정 트리 분석- 특징량 중요도

# %%
model.feature_importances_

# %%
pd.DataFrame(model.feature_importances_, index=x.columns)
# Out:
#                                      0
# alcohol                       0.000000
# malic_acid                    0.008804
# total_phenols                 0.000000
# flavanoids                    0.072269
# nonflavanoid_phenols          0.000000
# proanthocyanins               0.000000
# color_intensity               0.109832
# hue                           0.000000
# od280/od315_of_diluted_wines  0.404506
# proline                       0.404589

# %% [markdown]
# #### wine의 재배종 3개를 구분하는 특징량 중, od280/od315 of diluted wines 가 분류에 미치는 영향이 가장 크다.
